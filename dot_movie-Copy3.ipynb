# %%
import numpy as np
from astropy.io import fits
from scipy.optimize import curve_fit
import os
import glob
from pylab import *
from math import e
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.ndimage import rotate
import matplotlib.animation as animation
from IPython.display import HTML
import pathlib

# %%
notes = "spring break data"

#add notes here. 

#NOTE: GO TO CELL

# %%
#change to filenames and folder name
foldername_date = "20260306"
foldername = "springgenie"


#change to your path
rootpath = pathlib.Path(r"C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test")
filepath = rootpath / (foldername_date + "_data") / foldername
folderpath_date = rootpath / (foldername_date + "_data")
path1 = (filepath /(foldername +"_fits")).__str__()+"/*.fits"

print(path1)


#path1  = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/temp_fits/1-833-stability*11*.fits"
#path1 = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20250917_fits/*.fits"
#path1 = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/morning5237_0926_fits/*.fits"

fits_list = glob.glob(path1)
fits_list = np.sort(fits_list,kind='standardsort')

#fits_list = sorted(fits_list, key=lambda x: int(re.search(r'fanoff(\d+)', x).group(1)))


#sorted_list = sorted(fits_list, key=lambda x: int(re.search(r'stability(\d+)', x).group(1)))

#np.set_printoptions(threshold=np.inf)  # show entire array, no truncation


# only keep files that match "stability...123"
#fits_list = [f for f in fits_list if re.search(r'stability(\d+)', f)]

#sorted_list = sorted(fits_list, key=lambda x: int(re.search(r'stability(\d+)', x).group(1)))

for f in fits_list:
    print(f)

#print(fits_list)
#print(len(fits_list))


#print(fits_list[:5])   # first few
#print(fits_list[-5:])  # last few
# Out:
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits/*.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0001 26-03-06 16-41-07.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0002 26-03-06 16-42-07.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0003 26-03-06 16-43-07.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0004 26-03-06 16-44-08.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0005 26-03-06 16-45-08.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0006 26-03-06 16-46-08.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0007 26-03-06 16-47-08.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0008 26-03-06 16-48-08.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0009 26-03-06 16-49-09.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0010 26-03-06 16-50-09.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0011 26-03-06 16-51-09.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0012 26-03-06 16-52-09.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0013 26-03-06 16-53-09.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0014 26-03-06 16-54-10.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0015 26-03-06 16-55-10.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0016 26-03-06 16-56-10.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0017 26-03-06 16-57-10.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0018 26-03-06 16-58-10.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0019 26-03-06 16-59-10.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0020 26-03-06 17-00-11.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0021 26-03-06 17-01-11.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0022 26-03-06 17-02-11.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0023 26-03-06 17-03-11.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0024 26-03-06 17-04-11.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0025 26-03-06 17-05-12.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0026 26-03-06 17-06-12.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0027 26-03-06 17-07-12.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0028 26-03-06 17-08-12.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0029 26-03-06 17-09-12.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0030 26-03-06 17-10-12.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0031 26-03-06 17-11-12.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0032 26-03-06 17-12-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0033 26-03-06 17-13-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0034 26-03-06 17-14-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0035 26-03-06 17-15-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0036 26-03-06 17-16-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0037 26-03-06 17-17-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0038 26-03-06 17-18-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0039 26-03-06 17-19-13.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0040 26-03-06 17-20-14.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0041 26-03-06 17-21-14.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0042 26-03-06 17-22-14.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0043 26-03-06 17-23-14.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0044 26-03-06 17-24-14.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0045 26-03-06 17-25-14.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image0046 26-03-06 17-26-14.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image
fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9950 26-03-13 15-51-53.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9951 26-03-13 15-52-53.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9952 26-03-13 15-53-53.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9953 26-03-13 15-54-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9954 26-03-13 15-55-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9955 26-03-13 15-56-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9956 26-03-13 15-57-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9957 26-03-13 15-58-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9958 26-03-13 15-59-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9959 26-03-13 16-00-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9960 26-03-13 16-01-54.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9961 26-03-13 16-02-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9962 26-03-13 16-03-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9963 26-03-13 16-04-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9964 26-03-13 16-05-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9965 26-03-13 16-06-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9966 26-03-13 16-07-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9967 26-03-13 16-08-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9968 26-03-13 16-09-55.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9969 26-03-13 16-10-56.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9970 26-03-13 16-11-56.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9971 26-03-13 16-12-56.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9972 26-03-13 16-13-56.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9973 26-03-13 16-14-56.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9974 26-03-13 16-15-56.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9975 26-03-13 16-16-56.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9976 26-03-13 16-17-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9977 26-03-13 16-18-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9978 26-03-13 16-19-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9979 26-03-13 16-20-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9980 26-03-13 16-21-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9981 26-03-13 16-22-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9982 26-03-13 16-23-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9983 26-03-13 16-24-57.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9984 26-03-13 16-25-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9985 26-03-13 16-26-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9986 26-03-13 16-27-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9987 26-03-13 16-28-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9988 26-03-13 16-29-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9989 26-03-13 16-30-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9990 26-03-13 16-31-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9991 26-03-13 16-32-58.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9992 26-03-13 16-33-59.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9993 26-03-13 16-34-59.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9994 26-03-13 16-35-59.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9995 26-03-13 16-36-59.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9996 26-03-13 16-37-59.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9997 26-03-13 16-38-59.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9998 26-03-13 16-39-59.fits
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springgenie\springgenie_fits\image9999 26-03-13 16-40-59.fits

# %%
'''
def openfits(path):
    
    hdu = fits.open(path)
    data = hdu[0].data    #data
    hdr = hdu[0].header    # headers
    
    #image_data = fits.getdata(path, ext=0)
    #image_data = np.flip(np.transpose(image_data), axis=1) #flip data by 90 degrees
    #image_data = np.flip(image_data, axis=(0, 1)) #flip data by 180 degrees
    
    #data = np.flip(np.transpose(data), axis=1) #flip data by 90 degrees
    data = np.flip(data, axis=(0, 1)) #flip data by 180 degrees
    
    image_data = data
    
    shape = image_data.shape #shape
    
    return hdu, data, hdr, image_data, shape
    
    '''

#use with to close file 

def openfits(path):
    with fits.open(path) as hdu:
        data = hdu[0].data    # numpy array (lazy loaded)
        hdr  = hdu[0].header  # header
        
        # Flip/transform the data
        data = np.flip(data, axis=(0, 1)) 
        
        image_data = data.copy()  # force load into memory
        shape = image_data.shape
    
    return None, image_data, hdr, image_data, shape

# %%
hdu = []
data = []
hdr = []
image_data = []
shape = []

for fits_file in fits_list:
    hdu_temp, data_temp, hdr_temp, image_data_temp, shape_temp = openfits(fits_file)
    
    #data_temp = data_temp[0, :, :]
    
    hdu.append(hdu_temp)
    data.append(data_temp)
    hdr.append(hdr_temp)
    image_data.append(image_data_temp)
    shape.append(shape_temp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[126], line 8
#       5 shape = []
#       7 for fits_file in fits_list:
# ----> 8     hdu_temp, data_temp, hdr_temp, image_data_temp, shape_temp = openfits(fits_file)
#      10     #data_temp = data_temp[0, :, :]
#      12     hdu.append(hdu_temp)
#
# Cell In[125], line 33, in openfits(path)
#      30     # Flip/transform the data
#      31     data = np.flip(data, axis=(0, 1))
# ---> 33     image_data = data.copy()  # force load into memory
#      34     shape = image_data.shape
#      36 return None, image_data, hdr, image_data, shape
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10,10))
plt.imshow(data[0], cmap='viridis', vmin = 0, vmax = 100)
#plt.title("title", fontsize=20)
#plt.plot(sum_dat)
#cbar = plt.colorbar()
#cbar.set_label('Ec', fontsize=15)
#plt.colorbar()

# %%
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(data[0], cmap='viridis', vmin=0, vmax=100)

def update(frame):
    im.set_array(data[frame])
    return [im]

#ani = animation.FuncAnimation(fig, update, frames=len(data), interval=200, blit=True)

# show inline in notebook
#HTML(ani.to_jshtml())

# %%
print(len(data[0][0]))
print(len(data[0]))
print(data[0].shape)
# Out:
# 1920
# 1080
# (1080, 1920)

# %%
profiles_x = []
profiles_y = []

for img in data:
    # collapse along y (rows); psf along x
    profiles_x.append(np.sum(img, axis=0))

    # collapse along x (columns); psf along y
    profiles_y.append(np.sum(img, axis=1))

profiles_x = np.array(profiles_x) 
profiles_y = np.array(profiles_y)

# %%
filename = os.path.basename(filepath)

log_path = filepath / (foldername + ".txt")

print(log_path)
print(folderpath_date)

print(folderpath_date / foldername / foldername)
# Out:
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springbreak\springbreak.txt
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springbreak\springbreak

# %%
import pandas as pd

# --- 2. Load the timestamp file ---
# Your text file isn’t quite a CSV, so we’ll parse it carefully
df_times = pd.read_csv(
    log_path,
    sep=r'\t+',              # split by tabs
    engine='python',
    skiprows=2,              # skip the first two header lines
    names=["Filename", "Creation Date"]
)

# Strip whitespace just in case
df_times["Filename"] = df_times["Filename"].str.strip()
df_times["Creation Date"] = df_times["Creation Date"].str.strip()

# %%
# --- 3. Create figure and subplots ---
fig = plt.figure(figsize=(10, 8))
gs = fig.add_gridspec(2, 2, width_ratios=[4,1], height_ratios=[1,4], wspace=0.0, hspace=0.0)

ax_img = fig.add_subplot(gs[1,0])
ax_x   = fig.add_subplot(gs[0,0], sharex=ax_img)
ax_y   = fig.add_subplot(gs[1,1], sharey=ax_img)
fig.add_subplot(gs[0,1]).axis("off")

im = ax_img.imshow(data[0], cmap="viridis", origin="lower", vmin=0, vmax=100, aspect="auto")

profile_x = np.sum(data[0], axis=0)
profile_y = np.sum(data[0], axis=1)

line_x, = ax_x.plot(np.arange(data[0].shape[1]), profile_x)
line_y, = ax_y.plot(profile_y, np.arange(data[0].shape[0]))

ax_x.set_xlim(ax_img.get_xlim())
ax_y.set_ylim(ax_img.get_ylim())

ax_x.tick_params(labelbottom=False)
ax_y.tick_params(labelleft=False)
ax_x.set_ylabel("counts")
ax_y.set_xlabel("counts")
ax_x.grid()
ax_y.grid()

max_x = max(np.sum(img, axis=0).max() for img in data)
max_y = max(np.sum(img, axis=1).max() for img in data)
min_x = max(np.sum(img, axis=0).min() for img in data)
min_y = max(np.sum(img, axis=1).min() for img in data)

ax_x.set_ylim(min_x - 200, max_x - 200)
ax_y.set_xlim(min_y - 200, max_y)

# --- 4. Add a text label for the creation date ---
timestamp_text = ax_img.text(
    0.02, 0.98, "", 
    transform=ax_img.transAxes, 
    color="white", 
    fontsize=12, 
    verticalalignment="top",
    bbox=dict(facecolor="black", alpha=0.5, edgecolor="none", pad=3)
)

# --- 5. Update function ---
def update(frame):
    img = data[frame]
    im.set_array(img)

    profile_x = np.sum(img, axis=0)
    profile_y = np.sum(img, axis=1)
    line_x.set_ydata(profile_x)
    line_y.set_xdata(profile_y)

    # Get matching creation date from the DataFrame
    if frame < len(df_times):
        timestamp = df_times.iloc[frame]["Creation Date"]
        timestamp_text.set_text(f"{timestamp}")
    else:
        timestamp_text.set_text("")

    return [im, line_x, line_y, timestamp_text]

ani = animation.FuncAnimation(fig, update, frames=len(data), interval=200, blit=True)
HTML(ani.to_jshtml())

# --- 6. (Optional) Save video ---
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)
ani.save(folderpath_date / foldername / (foldername + ".mp4"), writer=writer)
# Out:
# Animation size has reached 21043751 bytes, exceeding the limit of 20971520.0. If you're sure you want a larger animation embedded, set the animation.embed_limit rc parameter to a larger value (in MB). This and further frames will be dropped.

# %%
'''
fig = plt.figure(figsize=(10,8))

#2x2 grid equal sizes
gs = fig.add_gridspec(2, 2, width_ratios=[4,1], height_ratios=[1,4], wspace=0.0, hspace=0.0)

ax_img = fig.add_subplot(gs[1,0])
ax_x   = fig.add_subplot(gs[0,0], sharex=ax_img)  # x (top)
ax_y   = fig.add_subplot(gs[1,1], sharey=ax_img)  # y (right)

#hide the empty top-right cell
fig.add_subplot(gs[0,1]).axis("off")

#primary image
im = ax_img.imshow(data[0], cmap="viridis", origin="lower", vmin=0, vmax=100, aspect="auto")

#profiles
profile_x = np.sum(data[0], axis=0)
profile_y = np.sum(data[0], axis=1)

line_x, = ax_x.plot(np.arange(data[0].shape[1]), profile_x)          # x psf
line_y, = ax_y.plot(profile_y, np.arange(data[0].shape[0]))          # y psf

#sync axes so they align
ax_x.set_xlim(ax_img.get_xlim())
ax_y.set_ylim(ax_img.get_ylim())

#ticks
ax_x.tick_params(labelbottom=False)
ax_y.tick_params(labelleft=False)

ax_x.set_ylabel("counts")
ax_y.set_xlabel("counts")

ax_x.grid()
ax_y.grid()


# compute global maxima across ALL frames
max_x = max(np.sum(img, axis=0).max() for img in data)
max_y = max(np.sum(img, axis=1).max() for img in data)

min_x = max(np.sum(img, axis=0).min() for img in data)
min_y = max(np.sum(img, axis=1).min() for img in data)

ax_x.set_ylim(min_x-200, max_x-200)   # add headroom
ax_y.set_xlim(min_y-200, max_y)

def update(frame):
    img = data[frame]
    im.set_array(img)

    profile_x = np.sum(img, axis=0)
    profile_y = np.sum(img, axis=1)

    line_x.set_ydata(profile_x)
    line_y.set_xdata(profile_y)
    return [im, line_x, line_y]

ani = animation.FuncAnimation(fig, update, frames=len(data), interval=200, blit=True)

HTML(ani.to_jshtml())

#comment out below to not save video 
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)

ani.save("psf_movie_bigshakeA.mp4", writer=writer)


'''
# Out:
# '\nfig = plt.figure(figsize=(10,8))\n\n#2x2 grid equal sizes\ngs = fig.add_gridspec(2, 2, width_ratios=[4,1], height_ratios=[1,4], wspace=0.0, hspace=0.0)\n\nax_img = fig.add_subplot(gs[1,0])\nax_x   = fig.add_subplot(gs[0,0], sharex=ax_img)  # x (top)\nax_y   = fig.add_subplot(gs[1,1], sharey=ax_img)  # y (right)\n\n#hide the empty top-right cell\nfig.add_subplot(gs[0,1]).axis("off")\n\n#primary image\nim = ax_img.imshow(data[0], cmap="viridis", origin="lower", vmin=0, vmax=100, aspect="auto")\n\n#profiles\nprofile_x = np.sum(data[0], axis=0)\nprofile_y = np.sum(data[0], axis=1)\n\nline_x, = ax_x.plot(np.arange(data[0].shape[1]), profile_x)          # x psf\nline_y, = ax_y.plot(profile_y, np.arange(data[0].shape[0]))          # y psf\n\n#sync axes so they align\nax_x.set_xlim(ax_img.get_xlim())\nax_y.set_ylim(ax_img.get_ylim())\n\n#ticks\nax_x.tick_params(labelbottom=False)\nax_y.tick_params(labelleft=False)\n\nax_x.set_ylabel("counts")\nax_y.set_xlabel("counts")\n\nax_x.grid()\nax_y.grid()\n\n\n# compute global maxima across ALL frames\nmax_x = max(np.sum(img, axis=0).max() for img in data)\nmax_y = max(np.sum(img, axis=1).max() for img in data)\n\nmin_x = max(np.sum(img, axis=0).min() for img in data)\nmin_y = max(np.sum(img, axis=1).min() for img in data)\n\nax_x.set_ylim(min_x-200, max_x-200)   # add headroom\nax_y.set_xlim(min_y-200, max_y)\n\ndef update(frame):\n    img = data[frame]\n    im.set_array(img)\n\n    profile_x = np.sum(img, axis=0)\n    profile_y = np.sum(img, axis=1)\n\n    line_x.set_ydata(profile_x)\n    line_y.set_xdata(profile_y)\n    return [im, line_x, line_y]\n\nani = animation.FuncAnimation(fig, update, frames=len(data), interval=200, blit=True)\n\nHTML(ani.to_jshtml())\n\n#comment out below to not save video \nWriter = animation.writers[\'ffmpeg\']\nwriter = Writer(fps=20, metadata=dict(artist=\'Me\'), bitrate=1800)\n\nani.save("psf_movie_bigshakeA.mp4", writer=writer)\n\n\n'

# %%
# example fit for just first frame


def gaussian(x, amp, mu, sigma, offset):
    return amp * np.exp(-0.5 * ((x - mu)/sigma)**2) + offset


img = data[0]

profile_x = np.sum(img, axis=0)
profile_y = np.sum(img, axis=1)

x_vals = np.arange(profile_x.size)
p0_x = [profile_x.max(), profile_x.argmax(), 5, np.median(profile_x)]  # initial guess
popt_x, pcov_x = curve_fit(gaussian, x_vals, profile_x, p0=p0_x)

y_vals = np.arange(profile_y.size)
p0_y = [profile_y.max(), profile_y.argmax(), 5, np.median(profile_y)]
popt_y, pcov_y = curve_fit(gaussian, y_vals, profile_y, p0=p0_y)

# popt_x = [amp, mu, sigma, offset] for x-profile
# popt_y = [amp, mu, sigma, offset] for y-profile

# Generate smooth fit curves
x_fit = gaussian(x_vals, *popt_x)
y_fit = gaussian(y_vals, *popt_y)

print("X fit:", popt_x)
print("Y fit:", popt_y)
# Out:
# X fit: [8.15224906e+02 1.01481073e+03 4.78866579e+00 1.63460581e+04]
# Y fit: [6.60992761e+02 6.15205897e+02 7.55704018e+00 2.90571259e+04]

# %%
plot(np.arange(data[0].shape[1]), profile_x) 
plot(x_vals, x_fit, 'r--', label="Gaussian fit")

# %%
plot(np.arange(data[0].shape[0]), profile_y) 
plot(y_vals, y_fit, 'r--', label="Gaussian fit")

# %%
def gaussian(x, amp, mu, sigma, offset):
    return amp * np.exp(-0.5 * ((x - mu)/sigma)**2) + offset

#initialize
amps_x, mus_x, sigmas_x, offsets_x = [], [], [], []
amps_y, mus_y, sigmas_y, offsets_y = [], [], [], []

for img in data:
    # collapse
    profile_x = np.sum(img, axis=0)
    profile_y = np.sum(img, axis=1)

    #fit x
    x_vals = np.arange(profile_x.size)
    p0_x = [profile_x.max(), profile_x.argmax(), 5, np.median(profile_x)]
    try:
        popt_x, _ = curve_fit(gaussian, x_vals, profile_x, p0=p0_x)
    except RuntimeError:
        popt_x = [np.nan]*4

    amps_x.append(popt_x[0])
    mus_x.append(popt_x[1])
    sigmas_x.append(popt_x[2])
    offsets_x.append(popt_x[3])

    #fit y
    y_vals = np.arange(profile_y.size)
    p0_y = [profile_y.max(), profile_y.argmax(), 5, np.median(profile_y)]
    try:
        popt_y, _ = curve_fit(gaussian, y_vals, profile_y, p0=p0_y)
    except RuntimeError:
        popt_y = [np.nan]*4

    amps_y.append(popt_y[0])
    mus_y.append(popt_y[1])
    sigmas_y.append(popt_y[2])
    offsets_y.append(popt_y[3])

#to np.array
amps_x = np.array(amps_x)
mus_x = np.array(mus_x)
sigmas_x = np.array(sigmas_x)
offsets_x = np.array(offsets_x)

amps_y = np.array(amps_y)
mus_y = np.array(mus_y)
sigmas_y = np.array(sigmas_y)
offsets_y = np.array(offsets_y)

# %%
#need to add cut to data for bad fits and NANs 

def filter_fits(amps_x, mus_x, sigmas_x, offsets_x,
                amps_y, mus_y, sigmas_y, offsets_y,
                fwhm_min, fwhm_max):
    
    fwhm_x = 2.355 * sigmas_x
    fwhm_y = 2.355 * sigmas_y

    #mask for NANs & infs
    finite_mask = (
        np.isfinite(amps_x) & np.isfinite(mus_x) & np.isfinite(sigmas_x) & np.isfinite(offsets_x) &
        np.isfinite(amps_y) & np.isfinite(mus_y) & np.isfinite(sigmas_y) & np.isfinite(offsets_y)
    )

    #mask for FWHM
    fwhm_mask = (
        (fwhm_x > fwhm_min) & (fwhm_x < fwhm_max) &
        (fwhm_y > fwhm_min) & (fwhm_y < fwhm_max)
    )

    #both 
    mask = finite_mask & fwhm_mask

    return (amps_x[mask], mus_x[mask], sigmas_x[mask], offsets_x[mask],
            amps_y[mask], mus_y[mask], sigmas_y[mask], offsets_y[mask],
            fwhm_x[mask], fwhm_y[mask], mask)

# %%
filtered = filter_fits(amps_x, mus_x, sigmas_x, offsets_x,
                       amps_y, mus_y, sigmas_y, offsets_y,
                       fwhm_min=1, fwhm_max=500)

filtered
# Out:
# (array([815.22490594, 677.04075712, 534.1006084 , ..., 642.72110116,
#         636.98512003, 682.50000949], shape=(14174,)),
#  array([1014.81072706, 1014.24949967, 1016.68582295, ..., 1021.21509836,
#         1020.94104857, 1022.44050096], shape=(14174,)),
#  array([4.78866579, 5.7687886 , 8.4542216 , ..., 5.76306289, 5.98947644,
#         5.70083639], shape=(14174,)),
#  array([16346.05808606, 16346.13690071, 16347.36851997, ...,
#         16342.94705378, 16337.54984026, 16336.70997829], shape=(14174,)),
#  array([660.99276115, 709.16038282, 800.43648908, ..., 620.78242234,
#         705.3553829 , 777.01387638], shape=(14174,)),
#  array([615.20589657, 610.69893253, 611.78527223, ..., 812.10362976,
#         813.69063962, 813.37881823], shape=(14174,)),
#  array([7.55704018, 5.70138448, 5.89584611, ..., 6.1485354 , 6.22319857,
#         5.64350813], shape=(14174,)),
#  array([29057.12594318, 29059.4798246 , 29061.51536441, ...,
#         29053.8661516 , 29043.19998909, 29041.89280011], shape=(14174,)),
#  array([11.27730793, 13.58549716, 19.90969187, ..., 13.57201312,
#         14.10521702, 13.42546969], shape=(14174,)),
#  array([17.79682961, 13.42676045, 13.8847176 , ..., 14.47980086,
#         14.65563263, 13.29046165], shape=(14174,)),
#  array([ True,  True,  True, ...,  True,  True,  True], shape=(14174,)))

# %%
(amps_x_f, mus_x_f, sigmas_x_f, offsets_x_f,
 amps_y_f, mus_y_f, sigmas_y_f, offsets_y_f,
 fwhm_x_f, fwhm_y_f, mask) = filtered

print(len(amps_x_f))
print(len(fwhm_y_f))
# Out:
# 14174
# 14174

# %%
#recenter relative to first frame
mu_x_rel = mus_x_f - mus_x_f[0]
mu_y_rel = mus_y_f - mus_y_f[0]

frames = np.arange(len(mu_x_rel))

print(mu_x_rel)
print(mu_y_rel)
# Out:
# [ 0.         -0.56122739  1.87509589 ...  6.4043713   6.13032151
#   7.6297739 ]
# [  0.          -4.50696404  -3.42062433 ... 196.89773319 198.48474306
#  198.17292166]

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

axs[0].plot(frames, mu_x_rel, color='blue')
axs[0].set_ylabel("X centroid shift (pixels)")
#axs[0].set_title("X centroid over time")
axs[0].grid(True)
linex = axs[0].plot(
    [frames[0], frames[-1]],
    [mu_x_rel[0], mu_x_rel[-1]],
    color='red'
)[0]   

#slope
slopex = (mu_x_rel[-1] - mu_x_rel[0]) / (frames[-1] - frames[0])


axs[0].legend([linex], [f"Slope = {slopex:.4f} px/frame"])


axs[1].plot(frames, mu_y_rel, color='green')
axs[1].set_xlabel("Frame")
axs[1].set_ylabel("Y centroid shift (pixels)")
#axs[1].set_title("Y centroid over time")
axs[1].grid(True)
liney = axs[1].plot(
    [frames[0], frames[-1]],
    [mu_y_rel[0], mu_y_rel[-1]],
    color='red', alpha=0.5
)[0]   #

#slope
slopey = (mu_y_rel[-1] - mu_y_rel[0]) / (frames[-1] - frames[0])


axs[1].legend([liney], [f"Slope = {slopey:.4f} px/frame"])

plt.tight_layout()
plt.show()

fig.savefig(folderpath_date / (foldername + "/" + foldername + "_position"), dpi=300, bbox_inches="tight")

# %%
# Compute FWHM
FWHM_factor = 2 * np.sqrt(2 * np.log(2))  # ~2.35482
FWHM_x = sigmas_x_f * FWHM_factor
FWHM_y = sigmas_y_f * FWHM_factor

frames = np.arange(len(FWHM_x))

print(FWHM_x)
print(FWHM_y)
# Out:
# [11.27644618 13.58445904 19.90817049 ... 13.57097602 14.10413918
#  13.4244438 ]
# [17.79546969 13.42573446 13.88365661 ... 14.4786944  14.65451274
#  13.28944607]

# %%
# Plot X and Y FWHM separately
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

#x FWHM
axs[0].plot(frames, FWHM_x, color='blue')
axs[0].set_ylabel("FWHM X (pixels)")
#axs[0].set_title("X FWHM over frames")
axs[0].grid(True)
axs[0].grid(True)
linexfwhm = axs[0].plot(
    [frames[0], frames[-1]],
    [FWHM_x[0], FWHM_x[-1]],
    color='red', alpha=0.5
)[0]   

# slope
slopexfwhm = (FWHM_x[-1] - FWHM_x[0]) / (frames[-1] - frames[0])

axs[0].legend([linexfwhm], [f"Slope = {slopexfwhm:.4f} px/frame"])


#y FWHM
axs[1].plot(frames, FWHM_y, color='green')
axs[1].set_xlabel("Frame")
axs[1].set_ylabel("FWHM Y (pixels)")
#axs[1].set_title("Y FWHM over frames")
axs[1].grid(True)
lineyfwhm = axs[1].plot(
    [frames[0], frames[-1]],
    [FWHM_y[0], FWHM_y[-1]],
    color='red', alpha=0.5
)[0]  

#slope
slopeyfwhm = (FWHM_y[-1] - FWHM_y[0]) / (frames[-1] - frames[0])

axs[1].legend([lineyfwhm], [f"Slope = {slopeyfwhm:.4f} px/frame"])


plt.tight_layout()
plt.show()


fig.savefig(folderpath_date / (foldername + "/" + foldername + "_FWHM"), dpi=300, bbox_inches="tight")

# %%
print(np.mean(mu_x_rel))
print(np.mean(mu_y_rel))
print(np.std(mu_x_rel))
print(np.std(mu_y_rel))
# Out:
# -8.150487671287435
# 150.35114132000206
# 28.69819627066438
# 126.48880217591949

# %%
print(np.mean(FWHM_x))
print(np.mean(FWHM_y))
print(np.std(FWHM_x))
print(np.std(FWHM_y))
# Out:
# 13.83540402215833
# 13.713634973167919
# 2.834146864514226
# 2.559059826710448

# %%
def compute_fft(signal, dt):
    N = len(signal)
    fft_vals = np.fft.fft(signal - np.mean(signal))  # remove DC offset
    freqs = np.fft.fftfreq(N, d=dt)
    mask = freqs > 0
    return freqs[mask], np.abs(fft_vals[mask])**2


####################################################
#############
##CHANGE THIS DEPENDING ON FRAME RATE OF TEST
## comment out either top two or bottom two 
#############

# frame_rate = 52.37
# dt = 1.0 / frame_rate

frame_rate = 1/60
dt = 60.0


####################################################

#ffts
freqs_x, power_mu_x   = compute_fft(mu_x_rel, dt)
freqs_y, power_mu_y   = compute_fft(mu_y_rel, dt)
freqs_fx, power_fwhm_x = compute_fft(FWHM_x, dt)
freqs_fy, power_fwhm_y = compute_fft(FWHM_y, dt)


fig, axs = plt.subplots(2, 2, figsize=(12, 8))

axs[0,0].plot(freqs_x, power_mu_x)
axs[0,0].set_title("FFT of centroid (relative x)")
axs[0,0].set_xlabel("Frequency [Hz]")
axs[0,0].set_ylabel("Power")

axs[0,1].plot(freqs_y, power_mu_y)
axs[0,1].set_title("FFT of centroid (relative y)")
axs[0,1].set_xlabel("Frequency [Hz]")
axs[0,1].set_ylabel("Power")

axs[1,0].plot(freqs_fx, power_fwhm_x)
axs[1,0].set_title("FFT of FWHM (x)")
axs[1,0].set_xlabel("Frequency [Hz]")
axs[1,0].set_ylabel("Power")

axs[1,1].plot(freqs_fy, power_fwhm_y)
axs[1,1].set_title("FFT of FWHM (y))")
axs[1,1].set_xlabel("Frequency [Hz]")
axs[1,1].set_ylabel("Power")

plt.tight_layout()
plt.show()


fig.savefig(folderpath_date / foldername / (foldername + "_FFT"), dpi=300, bbox_inches="tight")

# %%
filename = os.path.basename(filepath)
num_data = len(fits_list)
    
creation_date_start = str(fits_list[0][-22:-5])
creation_date_stop = str(fits_list[-1][-22:-5])

# %%
# csv_path = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/collimated_beam_entry.xlsx"

# Load existing Excel
# df = pd.read_excel(csv_path, engine='openpyxl')

# Prepare new row as a dictionary
new_row = {
    'filename': filename,
    'number of frames': num_data,
    'start time': creation_date_start,
    'stop time': creation_date_stop,
    'notes': notes,
    'frame rate': frame_rate,
    'x position': np.mean(mu_x_rel*0.15),
    'x position std': np.std(mu_x_rel*0.15),
    'y position': np.mean(mu_y_rel*0.15),
    'y position std': np.std(mu_y_rel*0.15),
    'FWHM x': np.mean(FWHM_x*0.15),
    'FWHM x std': np.std(FWHM_x*0.15),
    'FWHM y': np.mean(FWHM_y*0.15),
    'FWHM y std': np.std(FWHM_y*0.15)
}
print(new_row)
# Append new row
# df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

# Save back
# df.to_excel(csv_path, index=False, engine='openpyxl')
pd.DataFrame([new_row]).to_csv(folderpath_date / foldername / (foldername + "_summary.csv"), index=False)
# Out:
# {'filename': 'springbreak', 'number of frames': 14174, 'start time': '26-03-06 16-44-47', 'stop time': '26-03-13 16-25-34', 'notes': 'spring break data', 'frame rate': 0.016666666666666666, 'x position': np.float64(-1.2225731506931155), 'x position std': np.float64(4.304729440599657), 'y position': np.float64(22.552671198000308), 'y position std': np.float64(18.97332032638792), 'FWHM x': np.float64(2.075310603323749), 'FWHM x std': np.float64(0.42512202967713386), 'FWHM y': np.float64(2.057045245975188), 'FWHM y std': np.float64(0.38385897400656727)}
