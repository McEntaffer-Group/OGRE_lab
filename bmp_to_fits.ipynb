# %%
import numpy as np
from astropy.io import fits
from scipy.optimize import curve_fit
import os
import glob
from pylab import *
from math import e
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.ndimage import rotate
from PIL import Image
import pandas as pd
import pathlib

from datetime import datetime

# %%
notes = ("static test of laser stand")

# %%
#path1  = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/temp/*.bmp"
#path1  = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20250917/*.bmp"
#path1 = "/Users/anh5866/OneDrive - The Pennsylvania State University/20250917/*.bmp"


#change for each file
foldername_date = "20260320"
foldername = "statictest"
rootpath = pathlib.Path(r"C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test")
#change to your path

filepath = rootpath / foldername_date / foldername
path1 = filepath.__str__() + "/*.bmp"

bmp_list = glob.glob(path1)
bmp_list = np.sort(bmp_list,kind='standardsort')

print(bmp_list)
print(len(bmp_list))
# Out:
# ['C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306\\springbreak\\springbreak0001 26-03-06 16-44-47.bmp'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306\\springbreak\\springbreak0002 26-03-06 16-45-47.bmp'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306\\springbreak\\springbreak0003 26-03-06 16-46-46.bmp'
#  ...
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306\\springbreak\\springbreak9997 26-03-13 16-23-35.bmp'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306\\springbreak\\springbreak9998 26-03-13 16-24-35.bmp'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306\\springbreak\\springbreak9999 26-03-13 16-25-34.bmp']
# 14174

# %%
nested_folder_path = rootpath / (foldername_date + "_data")
try:
    os.makedirs(nested_folder_path, exist_ok=True) # exist_ok=True prevents error if already exists
    print(f"Nested folder '{nested_folder_path}' created successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Nested folder 'C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data' created successfully.

# %%
nested_nested_folder_path = nested_folder_path / foldername
try:
    os.makedirs(nested_nested_folder_path, exist_ok=True) # exist_ok=True prevents error if already exists
    print(f"Nested folder '{nested_nested_folder_path}' created successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Nested folder 'C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springbreak' created successfully.

# %%
filename = os.path.basename(filepath)
num_data = len(bmp_list)


#for i in range(len(bmp_list)):
#    print(str(bmp_list[i][-21:-4]))
    
creation_date_start = str(bmp_list[0][-21:-4])
creation_date_stop = str(bmp_list[-1][-21:-4])

# %%
filename = os.path.basename(filepath)
num_data = len(bmp_list)


print(filename)
print(num_data)
print(creation_date_start)
print(creation_date_stop)
print(notes)
# Out:
# springbreak
# 14174
# 26-03-06 16-44-47
# 26-03-13 16-25-34
# spring break data

# %%
csv_path = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/collimated_beam_entry.xlsx"

# %%
log_path = (nested_nested_folder_path / filename).__str__() + ".txt"

with open(log_path, "w") as f:
    f.write("Filename\tCreation Date\n")
    f.write("-----------------------------------\n")

    for bmp_file in bmp_list:
        #get timestamp 
        dt_str = bmp_file[-21:-4]   
        
        #convert timestamp string to  datetime object
        creation_date = datetime.strptime(dt_str, "%y-%m-%d %H-%M-%S")

        #writee filename and timestamp
        f.write(f"{os.path.basename(bmp_file)}\t{creation_date}\n")

print("Creation dates saved to {log_path}")
# Out:
# Creation dates saved to {log_path}

# %%
input_folder = filepath
output_folder = nested_nested_folder_path / (foldername + "_fits")

print(input_folder)
print(output_folder)
# Out:
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306\springbreak
# C:\Users\jad507\OneDrive - The Pennsylvania State University\Pictures\Reverse Telescope Test\20260306_data\springbreak\springbreak_fits

# %%
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".bmp"):
        #load bmp
        img_path = os.path.join(input_folder, filename)
        img = Image.open(img_path).convert("L")  
        data = np.array(img)

        #save as FITS
        fits_filename = os.path.splitext(filename)[0] + ".fits"
        fits_path = os.path.join(output_folder, fits_filename)
        hdu = fits.PrimaryHDU(data)
        hdu.writeto(fits_path, overwrite=True)

# %%
path2 = output_folder.__str__() + "/*.fits"

fits_list = glob.glob(path2)
fits_list = np.sort(fits_list,kind='standardsort')

print(fits_list)
print(len(fits_list))
# Out:
# ['C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306_data\\springbreak\\springbreak_fits\\springbreak0001 26-03-06 16-44-47.fits'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306_data\\springbreak\\springbreak_fits\\springbreak0002 26-03-06 16-45-47.fits'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306_data\\springbreak\\springbreak_fits\\springbreak0003 26-03-06 16-46-46.fits'
#  ...
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306_data\\springbreak\\springbreak_fits\\springbreak9997 26-03-13 16-23-35.fits'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306_data\\springbreak\\springbreak_fits\\springbreak9998 26-03-13 16-24-35.fits'
#  'C:\\Users\\jad507\\OneDrive - The Pennsylvania State University\\Pictures\\Reverse Telescope Test\\20260306_data\\springbreak\\springbreak_fits\\springbreak9999 26-03-13 16-25-34.fits']
# 14174
